# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandogomes1993/Anotacoes/blob/main/funcoes_panda_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#                  Aqui seram passadas funçoes com explicaçao de como usar referente a biblioteca PANDAS


# formartando os valores com . e , ideal quando trabalha com valores monetarios inserir esses codicos logo depois de import
#     ✔ pd.options.display.float_format = '{:,.2f}'.format
#  ................................................................................................................................
# removendo a coluna visualizacao
#     ✔ .drop('coluna removida',axis=1)
# removendo a linha visualizacao         ## obs axis=1 remove coluna
#     ✔ .drop('30 por exemplo',axis=0)          axis=0 remove linha

#  ................................................................................................................................
# mostrando valores nulos
#     ✔ .loc[nome_arquivo.nome_coluna_a_verificar.isnull()]
# mostrando valores nao nulos
#     ✔ .loc[nome_arquivo.nome_coluna_a_verificar.notnull()]

#  ................................................................................................................................
# subistuir tudo que e nulo por qualquer valor ou palavra (poder ser usado como coluna tambem)
#    ✔.fillna('nome desejado')
#  ................................................................................................................................
# transforma qualquer coluna em indice exemplo subistituir a primeira coluna que normalmente vem numerada
# ✔.set_index(nome_arquivo.columns[numero coluna escolhido])

# retorna o indece ao padrao original numerico
# ✔.reset_index()
# removendo valores duplicados
# .drop_duplicates(inplace = True)
